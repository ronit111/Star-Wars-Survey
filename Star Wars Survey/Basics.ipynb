# %%
import pandas as pd
star_wars = pd.read_csv("star_wars.csv", encoding = "ISO-8859-1")

# %%
star_wars.head(10)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
# 6  3.292719e+09                                                Yes
# 7  3.292685e+09                                                Yes
# 8  3.292664e+09                                                Yes
# 9  3.292654e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# ...

# %%
star_wars = star_wars[pd.notnull(star_wars["RespondentID"])]

# %%
yes_no = {"Yes":True, "No":False}

cols = ["Have you seen any of the 6 films in the Star Wars franchise?",
       "Do you consider yourself to be a fan of the Star Wars film franchise?"]

for col in cols:
    star_wars[col] = star_wars[col].map(yes_no)
    
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
# 5                                               True
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %%
mapdict = {"Star Wars: Episode I  The Phantom Menace": True,
          "Star Wars: Episode II  Attack of the Clones":True,
          "Star Wars: Episode III  Revenge of the Sith":True,
          "Star Wars: Episode IV  A New Hope":True,
          "Star Wars: Episode V The Empire Strikes Back":True,
          "Star Wars: Episode VI Return of the Jedi":True,
          np.NaN: False}

import numpy as np
for col in star_wars.columns[3:9]:
    star_wars[col] = star_wars[col].map(mapdict)
    print (star_wars[col].unique())
# Out:
# [True False]
# [True False]
# [True False]
# [True False]
# [True False]
# [True False]

# %%
namedict = {}

for i, each in enumerate(star_wars.columns[3:9]):
    namedict[each] = "seen_{}".format(i+1)
    
star_wars.rename(columns = namedict, inplace = True)

# %%
star_wars[star_wars.columns[9:15]] = star_wars[star_wars.columns[9:15]].astype(float)

rankdict = {}
for i, each in enumerate(star_wars.columns[9:15]):
    rankdict[each] = "ranking_{}".format(i+1)

star_wars.rename(columns = rankdict, inplace = True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

means = star_wars.iloc[:,9:15].mean()
means.plot.bar()

# %% [markdown]
# Summary and Explanation..??

# %%
plt.bar(range(6), star_wars.iloc[:,3:9].sum())
# Out:
# <Container object of 6 artists>

# %% [markdown]
# Inferences...??

# %%
males = star_wars[star_wars["Gender"] == "Male"]
females = star_wars[star_wars["Gender"] == "Female"]

# %%
plt.bar(range(6), males.iloc[:,3:9].sum())
# Out:
# <Container object of 6 artists>

# %%
plt.bar(range(6), males.iloc[:,9:15].sum())
# Out:
# <Container object of 6 artists>

# %%
plt.bar(range(6), females.iloc[:,3:9].sum())
# Out:
# <Container object of 6 artists>

# %%
plt.bar(range(6), females.iloc[:,9:15].sum())
# Out:
# <Container object of 6 artists>

# %% [markdown]
# Inferences..??
